# %%
import pandas

f_raw = pandas.read_csv('./sources/data.csv', usecols=['Best Position',
                                                        'DistancesToClusterCenter no.0',
                                                        'DistancesToClusterCenter no.1',
                                                        'DistancesToClusterCenter no.2',
                                                        'DistancesToClusterCenter no.3',
                                                        'DistancesToClusterCenter no.4',
                                                        'DistancesToClusterCenter no.5',
                                                        'DistancesToClusterCenter no.6',
                                                        'DistancesToClusterCenter no.7',
                                                        'DistancesToClusterCenter no.8',
                                                        'DistancesToClusterCenter no.9',
                                                        'DistancesToClusterCenter no.10',
                                                        'DistancesToClusterCenter no.11',
                                                        'DistancesToClusterCenter no.12',
                                                        'DistancesToClusterCenter no.13',                                      
                                                        ]);

# %%
f_raw['Best Position']
# Out:
# 0        GK
# 1        RM
# 2        CB
# 3        LM
# 4        CB
#        ...
# 5254     GK
# 5255     CM
# 5256     CB
# 5257     CM
# 5258    CDM
# Name: Best Position, Length: 5259, dtype: object

# %%
f_raw.iloc[:, 0]
# Out:
# 0        GK
# 1        RM
# 2        CB
# 3        LM
# 4        CB
#        ...
# 5254     GK
# 5255     CM
# 5256     CB
# 5257     CM
# 5258    CDM
# Name: Best Position, Length: 5259, dtype: object

# %%
min_values = f_raw.iloc[:, 1:].idxmin(axis=1) # get the index of the min value for each row
min_values
# Out:
# 0       DistancesToClusterCenter no.3
# 1       DistancesToClusterCenter no.6
# 2       DistancesToClusterCenter no.2
# 3       DistancesToClusterCenter no.9
# 4       DistancesToClusterCenter no.2
#                     ...
# 5254    DistancesToClusterCenter no.3
# 5255    DistancesToClusterCenter no.5
# 5256    DistancesToClusterCenter no.2
# 5257    DistancesToClusterCenter no.5
# 5258    DistancesToClusterCenter no.4
# Length: 5259, dtype: object

# %%
min_values.hist(xrot=90)
# Out:
# <Axes: >

# %%
f_raw['Best Position'].hist(xrot=90)
# Out:
# <Axes: >

# %%
f_raw['Best Position'].value_counts()
# Out:
# Best Position
# CB     1050
# ST      736
# CAM     667
# GK      567
# RM      402
# CDM     377
# CM      322
# RB      271
# LM      243
# LB      214
# RWB     116
# LWB     112
# RW       97
# LW       66
# CF       19
# Name: count, dtype: int64

# %%
f_raw.groupby(['Best Position']).value_counts()
# Out:
# Best Position  DistancesToClusterCenter no.0  DistancesToClusterCenter no.1  DistancesToClusterCenter no.2  DistancesToClusterCenter no.3  DistancesToClusterCenter no.4  DistancesToClusterCenter no.5  DistancesToClusterCenter no.6  DistancesToClusterCenter no.7  DistancesToClusterCenter no.8  DistancesToClusterCenter no.9  DistancesToClusterCenter no.10  DistancesToClusterCenter no.11  DistancesToClusterCenter no.12  DistancesToClusterCenter no.13
# CAM            1.394383                       0.000000                       1.414214                       1.414214                       1.414214                       1.414214                       1.414214                       1.414214                       1.414214                       1.414214                       1.414214                        1.414214                        1.414214                        1.414214                           667
# ...
